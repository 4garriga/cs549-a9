# %% [markdown]
# # CS549 Machine Learning - Irfan Khan
# # Assignment 9: Optimized Neural Networks
#
# Updated from assignment designed by Yang Xu, Ex-Assistant Professor of Computer Science, San Diego State University
#
# **Total points: 18**
#
# There are two sections
#
# In this assignment, you will implement a feed-forward neural network for a multi-class classification task.

# %% [markdown]
# ## Section 1
# **Points: 5**
#
# In this section we will take the same example as in Assignment 3 (A3) but use a neural network instead of the legacy logistic reasoning model we used in assignment A3. We need to predict a student’s chance of admission in SDSU based on their results on two exams. The two exams are similar to MATH SAT and Verbal SAT exams
#
# We have historical data from previous students that we can use as a training set for the neural network logistic regression. For each training example, we have the student’s scores and the admissions decision.
#
# First recap the result from A3 assignment. We got a pretty good straight line decision boundary but a few datapoints are misclassified. Can we do any better with a Neural Network?<br>
#
# <img src='A9image1.png'>

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import torch

torch.manual_seed(0)
torch.use_deterministic_algorithms(True)
from torch import nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %% [markdown]
# ## Define a Neural Network
#
# Let us define a neural network with one hidden layer with ReLU activation function. The neural network outputs logits.

# %%
class NeuralNetworkLR(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        return x

# %% [markdown]
# ## Load and Pre-process the data for Section 1
#
# See https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader on data loader for more information.

# %%
# Read Excel data using Pandas

df = pd.read_excel("A3data.xlsx")
# features_df=df[['Exam1', 'Exam2']].to_numpy()

# Separate the data into features and labels, use float32 datatype

features_LR = torch.tensor(df[["Exam1", "Exam2"]].values, dtype=torch.float32)


avg_f = features_LR.mean(dim=0)
std_f = features_LR.std(dim=0)


# normalize feature data

features_norm = (features_LR - avg_f) / std_f


# Load Labels data. No need to normalize since data is only 0 or 1, use float32 datatype, unsqueeze to get compatible tensor with output needed later on

labels_LR = torch.tensor(df["Admission Decision"].values, dtype=torch.float32)
labels_LR = labels_LR.unsqueeze(1)

# Get data ready for torch

dataset = torch.utils.data.TensorDataset(features_norm, labels_LR)
# Create a data loader
data_loader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=False)

# %% [markdown]
# ## Create the Neural Network Model
#
# ***2 points****
#
# Define how many neurons in each layer (2,10,1), loss criterion and optimizer. nn.BCEWithLogitsLoss() is used for the criterion. We will use Adams and L2 regularization for the optimizer. Use lr=0.001, weigh_dcay = 0.0001.

# %%
# Create the neural network (2,10,1), model_LR
# BEGIN YOUR CODE #
model_LR = NeuralNetworkLR(2, 10, 1)

# Define the loss criterion and optimizer
lr = 1e-3
weight_decay = 1e-4

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_LR.parameters(), lr=lr, weight_decay=weight_decay)

# END YOUR CODE #

# %% [markdown]
# ## Train the Neural Network using back-propagation of gradients over 5000 Epochs
#
# **2 points**

# %%
num_epochs = 5000
for epoch in range(num_epochs):
    # Zero the gradients - fine here, only one mini-batch
    optimizer.zero_grad()

    # begin your code
    for i, (features_norm, labels_LR) in enumerate(data_loader):
        # Forward pass
        output = model_LR(features_norm)
        loss = criterion(output, labels_LR)

        # Backward pass
        loss.backward()

        # Optimize the weights and bias
        optimizer.step()

        # end your code

# %% [markdown]
# ## Predict Labels Using Trained Neural Network
#
# ***1 point***
#
# Use features_norm as input. Don't use the labels. Store the predicted classifications in a numpy array "pred_np". In PyTorch, torch.no_grad() is a context manager that temporarily disables gradient calculation. It is typically used during inference or evaluation, where you don’t need to compute gradients, as this reduces memory usage and speeds up computation.

# %%
pred = []  # use pred to store predicted classification: 1 or 0
pred_logits = []  # Use pred_logits to store logits

for i, (features_norm, labels_LR) in enumerate(data_loader):
    # Forward pass
    with torch.no_grad():
        # obtain predictions from trained model_LR.
        # START YOUR CODE
        predictions = model_LR(features_norm)
        # END YOUR CODE

    pred_logits = np.append(pred_logits, predictions.detach().numpy())

pred = [1 if entry >= 0 else 0 for entry in pred_logits]
pred_np = np.array(pred)  # Converts the pred list into a NumPy array.

# %% [markdown]
# ## Plot a scatter plot of the data set with labels obtained from the Trained Neural Network

# %%
# Define colors and labels based on pred values. Don't change the code in this cell.
colors = np.where(pred_np == 0, "black", "green")
# labels = np.where(pred_np == 0, "Not Admitted", "Admitted")

# Scatter plot with different colors based on pred
plt.scatter(features_LR[:, 0], features_LR[:, 1], c=colors, marker="o")

# Add labels and legend
plt.xlabel("Exam1 Score")
plt.ylabel("Exam2 Score")

legend_labels = ["Not Admitted", "Admitted"]
legend_markers = [
    plt.Line2D([0], [0], marker="o", color=color, label=label, markersize=10)
    for color, label in zip(["black", "green"], legend_labels)
]

# Add the legend
plt.legend(handles=legend_markers)

plt.show()

# %% [markdown]
# ## Expected Result **
#
# <img src = 'A9image2.png'>
#
# Compare with the original scatter plot. No misclassification. So we have improved over the legacy logistic reasoning approach!<br>
#
# <img src='A9image1.png'>

# %% [markdown]
# ## Predict classification for new data points ##
#
# Say (50,50),(35,99),(94,38),(80,80)

# %%
# Don't change code in this cell.
new_features_np = np.array([[50.0, 50.0], [35.0, 99.0], [94.0, 38.0], [80.0, 80.0]])

new_features_torch = torch.from_numpy(new_features_np).float()

new_features_norm = (new_features_torch - avg_f) / std_f


# Create a data loader
new_data_loader = torch.utils.data.DataLoader(
    new_features_norm, batch_size=4, shuffle=False
)
# Forward pass
new_feature_pred = []
new_pred_logits = []


for new_features_norm in new_data_loader:
    with torch.no_grad():
        new_predictions = model_LR(new_features_norm)
    new_pred_logits = np.append(new_pred_logits, new_predictions.detach().numpy())


new_feature_pred = [1 if entry >= 0 else 0 for entry in new_pred_logits]
print("Predicted Classifications", new_feature_pred)
# Out:
# Predicted Classifications [0, 0, 0, 1]

# %% [markdown]
# ## Expected Output
# Predicted Classifications [0 0 0 1]<br>
# Seems to make sense based on what the data sample scatter plot looks like! Neural network seems to have learnt that a very large score in Math1 will likely not lead to admittance if the Exam2 score is very low. Similarly seems to have learned that a very large score in Exam2 will likely not lead to admittance if the Exam1 score is very low

# %% [markdown]
# ## Section 2
#
# ***Total Points 13***

# %% [markdown]
# ## Task 1: Build a deeper neural network model
# **Points: 3**
#
# Implement the `NeuralNetModel1` class. The model takes a $28\times 28$ grey-scale image as input, and passes it through a deep neural network.
#
# The network has 2 hidden layers and 1 output layer, whose sizes are: 512 -> 512 -> 10. That is, the number of output classes is 10. The activation function for each hidden layer is `ReLU`.
#
# The input image should first be passed through a `nn.Flatten()` layer so that a 2D tensor becomes 1D.

# %%
class NeuralNetModel1(nn.Module):
    def __init__(self):
        super(NeuralNetModel1, self).__init__()
        ### START YOUR CODE ###
        self.flatten = nn.Flatten()  # 2d -> 1d
        self.hidden1 = nn.Linear(28 * 28, 512)
        self.hidden2 = nn.Linear(512, 512)
        self.output = nn.Linear(512, 10)
        ### END YOUR CODE ###

    def forward(self, x):
        ### START YOUR CODE ###
        # (28 x 28) -> relu -> 512 -> relu -> 512 -> 10
        x = self.flatten(x)
        x = nn.ReLU()(self.hidden1(x))
        x = nn.ReLU()(self.hidden2(x))
        logits = self.output(x)
        ### END YOUR CODE ###
        return logits

# %%
# Do not change the test code here
sample_input = torch.randn(5, 28, 28)
print("input size:", sample_input.size())

model1 = NeuralNetModel1()
with torch.no_grad():
    output = model1(sample_input)
print("output size:", output.size())
# Out:
# input size: torch.Size([5, 28, 28])
# output size: torch.Size([5, 10])

# %% [markdown]
# **Expected output**:
#
# input size: torch.Size([5, 28, 28])\
# output size: torch.Size([5, 10])
#
# ---
#
# ## Task 2: Use dataloader
# **Points: 1**
#
# Download the FashionMNIST dataset provided by PyTorch to the folder "data", which takes some time for the first time execution. The FashionMNIST dataset consists of a total of 60,000 examples for training and 10,000 examples for testing. Each example is a grayscale image of size 28x28 pixels and is associated with one of the following 10 classes:
#
# T-shirt/top
# Trouser
# Pullover
# Dress
# Coat
# Sandal
# Shirt
# Sneaker
# Bag
# Ankle boot
#
# The division is as follows:
#
# Training set: 60,000 examples
# Testing set: 10,000 examples
#
# Use the `DataLoader` module to wrap the loaded training and test data. Specify the `batch_size` to be 64 for both training and test dataloader. So for training we will have $60000/64 = \lceil 937.5 \rceil= 938$ batches and for testing we will have $10000/64 = \lceil 156.25 \rceil= 157$
#
# See <https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader> for more information.

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,  
    download=True,
    transform=ToTensor(),
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,  # False
    download=True,
    transform=ToTensor(),
)

batch_size = 64

### START YOUR CODE ###
# create train_loader and test_loader
train_loader = DataLoader(training_data, batch_size=batch_size, shuffle=False)  # True?
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
### END YOUR CODE ###
# Out:
# 100%|██████████| 26.4M/26.4M [00:04<00:00, 5.95MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 204kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.19MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 340kB/s]

# %%
# Do not change the test code here.
print("Training data size:", len(training_data))
print("Testing data size:", len(test_data))
print("No of Training Batches:", len(train_loader))
print("No of Test Batches:", len(test_loader))

count = 0
for batch in train_loader:
    X, y = batch
    print("X size:", X.size())
    print("y size:", y.size())
    count += 1
    if count > 0:
        break
# Out:
# Training data size: 60000
# Testing data size: 10000
# No of Training Batches: 938
# No of Test Batches: 157
# X size: torch.Size([64, 1, 28, 28])
# y size: torch.Size([64])

# %% [markdown]
# **Expected output**:
#
# Training data size: 60000<br>
# Testing data size: 10000<br>
# No of Training Batches: 938<br>
# No of Test Batches: 157<br>
# X size: torch.Size([64, 1, 28, 28])<br>
# y size: torch.Size([64])<br>

# %% [markdown]
# ## Task 3: Define loss function and optimizer
# **Points: 1**
#
# Use `nn.CrossEntropyLoss()` as the loss function for loss_fn, and use `torch.optim.SGD()` as the optimizer for optimizer_sgd. Specify the arguments for `SGD()`, including the learning rate correctly.
#
# See <https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html> and <https://pytorch.org/docs/stable/optim.html> for more information.

# %%
lr = 1e-3

### START YOUR CODE ###
loss_fn = nn.CrossEntropyLoss()
optimizer_sgd = torch.optim.SGD(model1.parameters(), lr=lr)
### END YOUR CODE ###

# %%
# Do not change the test code here
print(loss_fn)
print(type(optimizer_sgd))
# Out:
# CrossEntropyLoss()
# <class 'torch.optim.sgd.SGD'>

# %% [markdown]
# **Expected output**:
#
# CrossEntropyLoss()<br>
# <class 'torch.optim.sgd.SGD'>
#
# ---
#
# ## Task 4: Implement train and test functions
# **Points: 8**
#
# 2 points each for the next 4 cells
#
# Implement the code for training the model in `train()`. Implement the code for testing the model in `test()`. For the backpropagation step, you need to first zero out all gradients by calling `optimizer.zero_grad()` before carrying out `backward()` and `step()` to update parameters.
#
# In `test()`, you need to calculate the number of correct prediction in the current batch, and add it to the `correct` variable.
# Finally, you need to divide `correct` by the total number of test examples to obtain the test accuracy.

# %%
def train_loop(dataloader, model, loss_fn, optimizer, verbose=True):
    for i, (X, y) in enumerate(dataloader):
        # Compute prediction (pred) and loss
        ### START YOUR CODE ###
        pred = model(X)
        loss = loss_fn(pred, y)


        ### END YOUR CODE ###

        # Backpropagation
        ### START YOUR CODE ###
        # zero out gradients, specify loss function and optimizer to be used
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        ### END YOUR CODE ###

        if verbose and i % 100 == 0:
            loss = loss.item()
            current_step = i * len(X)
            print(
                f"loss: {loss:>7f}  [{current_step:>5d}/{len(dataloader.dataset):>5d}]"
            )

# %%
@torch.no_grad()# since we dont want gradients updated
def test_loop(dataloader, model, loss_fn):
    test_loss, correct = 0, 0

    for X, y in dataloader:
        ### START YOUR CODE ###
        # Compute prediction (pred) 
        #Compute test_loss
        # Add the number of correct prediction in the current batch to `correct`
        pred = model(X)
        test_loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        
        
        ### END YOUR CODE ###

    test_loss /= len(dataloader)
    ### START YOUR CODE ###
    #Represent the prediction accuracy in test_acc
    test_acc = correct / (len(dataloader.dataset))
    
    ### END YOUR CODE ###

    print(f"Test Error: \n Accuracy: {(100*test_acc):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# Next, execute the following cell to start the training and testing loop. Be patient - this cell execution is time-consuming!

# %%
model1 = NeuralNetModel1()  # Reset the model
### START YOUR CODE ###

optimizer_sgd = torch.optim.SGD(model1.parameters(), lr=lr)

# Because the model1 is reset, the optimizer (optimizer_sgd), also needs to be redefined. Do that here.

### END YOUR CODE ###

epochs = 10
for t in range(epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    ### START YOUR CODE ###
    # Run train_loop followed by test_loop
    train_loop(train_loader, model1, loss_fn, optimizer_sgd)
    test_loop(test_loader, model1, loss_fn)
    

    ### END YOUR CODE ###

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.297473  [    0/60000]
# loss: 2.286357  [ 6400/60000]
# loss: 2.259302  [12800/60000]
# loss: 2.253699  [19200/60000]
# loss: 2.248904  [25600/60000]
# loss: 2.201912  [32000/60000]
# loss: 2.223741  [38400/60000]
# loss: 2.180775  [44800/60000]
# loss: 2.160697  [51200/60000]
# loss: 2.136777  [57600/60000]
# Test Error:
#  Accuracy: 40.5%, Avg loss: 2.131347
#
# Epoch 2
# -------------------------------
# loss: 2.139307  [    0/60000]
# loss: 2.129066  [ 6400/60000]
# loss: 2.058961  [12800/60000]
# loss: 2.079230  [19200/60000]
# loss: 2.046653  [25600/60000]
# loss: 1.963566  [32000/60000]
# loss: 2.013318  [38400/60000]
# loss: 1.922106  [44800/60000]
# loss: 1.914247  [51200/60000]
# loss: 1.853637  [57600/60000]
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.846828
#
# Epoch 3
# -------------------------------
# loss: 1.884177  [    0/60000]
# loss: 1.850695  [ 6400/60000]
# loss: 1.720190  [12800/60000]
# loss: 1.767348  [19200/60000]
# loss: 1.681183  [25600/60000]
# loss: 1.617359  [32000/60000]
# loss: 1.664024  [38400/60000]
# loss: 1.557188  [44800/60000]
# loss: 1.578765  [51200/60000]
# loss: 1.483480  [57600/60000]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 1.492702
#
# Epoch 4
# -------------------------------
# loss: 1.567355  [    0/60000]
# loss: 1.525728  [ 6400/60000]
# loss: 1.367466  [12800/60000]
# loss: 1.443105  [19200/60000]
# loss: 1.345991  [25600/60000]
# loss: 1.328390  [32000/60000]
# loss: 1.366733  [38400/60000]
# loss: 1.282093  [44800/60000]
# loss: 1.311523  [51200/60000]
# loss: 1.223969  [57600/60000]
# Test Error:
#  Accuracy: 63.6%, Avg loss: 1.240939
#
# Epoch 5
# -------------------------------
# loss: 1.323871  [    0/60000]
# loss: 1.297480  [ 6400/60000]
# loss: 1.126072  [12800/60000]
# loss: 1.233023  [19200/60000]
# loss: 1.125321  [25600/60000]
# loss: 1.137833  [32000/60000]
# loss: 1.183310  [38400/60000]
# loss: 1.108672  [44800/60000]
# loss: 1.141837  [51200/60000]
# loss: 1.071345  [57600/60000]
# Test Error:
#  Accuracy: 64.7%, Avg loss: 1.082787
#
# Epoch 6
# -------------------------------
# loss: 1.159127  [    0/60000]
# loss: 1.152156  [ 6400/60000]
# loss: 0.965490  [12800/60000]
# loss: 1.100691  [19200/60000]
# loss: 0.987473  [25600/60000]
# loss: 1.007172  [32000/60000]
# loss: 1.068091  [38400/60000]
# loss: 0.996791  [44800/60000]
# loss: 1.029457  [51200/60000]
# loss: 0.973945  [57600/60000]
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.979180
#
# Epoch 7
# -------------------------------
# loss: 1.042470  [    0/60000]
# loss: 1.057246  [ 6400/60000]
# loss: 0.854223  [12800/60000]
# loss: 1.012468  [19200/60000]
# loss: 0.899770  [25600/60000]
# loss: 0.914711  [32000/60000]
# loss: 0.991524  [38400/60000]
# loss: 0.923329  [44800/60000]
# loss: 0.951260  [51200/60000]
# loss: 0.908101  [57600/60000]
# Test Error:
#  Accuracy: 66.8%, Avg loss: 0.908153
#
# Epoch 8
# -------------------------------
# loss: 0.956193  [    0/60000]
# loss: 0.991565  [ 6400/60000]
# loss: 0.774452  [12800/60000]
# loss: 0.950500  [19200/60000]
# loss: 0.841937  [25600/60000]
# loss: 0.847598  [32000/60000]
# loss: 0.937481  [38400/60000]
# loss: 0.874375  [44800/60000]
# loss: 0.895258  [51200/60000]
# loss: 0.860754  [57600/60000]
# Test Error:
#  Accuracy: 67.9%, Avg loss: 0.857138
#
# Epoch 9
# -------------------------------
# loss: 0.890272  [    0/60000]
# loss: 0.942526  [ 6400/60000]
# loss: 0.715011  [12800/60000]
# loss: 0.904451  [19200/60000]
# loss: 0.801270  [25600/60000]
# loss: 0.797965  [32000/60000]
# loss: 0.897057  [38400/60000]
# loss: 0.840298  [44800/60000]
# loss: 0.853880  [51200/60000]
# loss: 0.824543  [57600/60000]
# Test Error:
#  Accuracy: 69.1%, Avg loss: 0.818600
#
# Epoch 10
# -------------------------------
# loss: 0.838179  [    0/60000]
# loss: 0.903035  [ 6400/60000]
# loss: 0.668896  [12800/60000]
# loss: 0.868706  [19200/60000]
# loss: 0.770859  [25600/60000]
# loss: 0.760196  [32000/60000]
# loss: 0.864731  [38400/60000]
# loss: 0.815105  [44800/60000]
# loss: 0.821969  [51200/60000]
# loss: 0.795188  [57600/60000]
# Test Error:
#  Accuracy: 70.5%, Avg loss: 0.787910
#
# Done!

# %% [markdown]
# **Expected output**
#
# The test accuracy from the last epoch should be above 70%.
#
# ---
#
# Next, train an ADAM optimizer. Note that the model needs be reset. Don't specify hyper-parameter values for beta1 and beta2. Default values (0.9, 0.999) will get used. Again, training for 10 epochs will take some time.

# %%
model1 = NeuralNetModel1()  # Reset the model

### START YOUR CODE ###
# Because the model1 is reset, the optimizer (optimizer_adam), also needs to be redefined. Do that here.
optimizer_adam = torch.optim.Adam(model1.parameters(), lr=lr)
### END YOUR CODE ###
epochs = 10
for t in range(epochs):
    print(f"Epoch {t + 1}\n-------------------------------")
    ### START YOUR CODE ###
    # train_loop and test_loop
    train_loop(train_loader, model1, loss_fn, optimizer_adam)
    test_loop(test_loader, model1, loss_fn)
    ### END YOUR CODE ###

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.311685  [    0/60000]
# loss: 0.552944  [ 6400/60000]
# loss: 0.396800  [12800/60000]
# loss: 0.504913  [19200/60000]
# loss: 0.506602  [25600/60000]
# loss: 0.407980  [32000/60000]
# loss: 0.383026  [38400/60000]
# loss: 0.500360  [44800/60000]
# loss: 0.501247  [51200/60000]
# loss: 0.536297  [57600/60000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.426278
#
# Epoch 2
# -------------------------------
# loss: 0.274810  [    0/60000]
# loss: 0.336869  [ 6400/60000]
# loss: 0.283324  [12800/60000]
# loss: 0.374985  [19200/60000]
# loss: 0.362622  [25600/60000]
# loss: 0.363251  [32000/60000]
# loss: 0.303045  [38400/60000]
# loss: 0.485777  [44800/60000]
# loss: 0.377183  [51200/60000]
# loss: 0.451673  [57600/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.393616
#
# Epoch 3
# -------------------------------
# loss: 0.208241  [    0/60000]
# loss: 0.317000  [ 6400/60000]
# loss: 0.230507  [12800/60000]
# loss: 0.314014  [19200/60000]
# loss: 0.344269  [25600/60000]
# loss: 0.357534  [32000/60000]
# loss: 0.272181  [38400/60000]
# loss: 0.435974  [44800/60000]
# loss: 0.302450  [51200/60000]
# loss: 0.416579  [57600/60000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.390149
#
# Epoch 4
# -------------------------------
# loss: 0.241362  [    0/60000]
# loss: 0.312499  [ 6400/60000]
# loss: 0.217325  [12800/60000]
# loss: 0.280290  [19200/60000]
# loss: 0.337178  [25600/60000]
# loss: 0.339388  [32000/60000]
# loss: 0.241526  [38400/60000]
# loss: 0.370782  [44800/60000]
# loss: 0.283257  [51200/60000]
# loss: 0.331249  [57600/60000]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.361806
#
# Epoch 5
# -------------------------------
# loss: 0.231514  [    0/60000]
# loss: 0.258382  [ 6400/60000]
# loss: 0.227064  [12800/60000]
# loss: 0.267900  [19200/60000]
# loss: 0.324365  [25600/60000]
# loss: 0.315756  [32000/60000]
# loss: 0.226494  [38400/60000]
# loss: 0.381922  [44800/60000]
# loss: 0.280119  [51200/60000]
# loss: 0.318875  [57600/60000]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.363418
#
# Epoch 6
# -------------------------------
# loss: 0.210807  [    0/60000]
# loss: 0.214125  [ 6400/60000]
# loss: 0.225872  [12800/60000]
# loss: 0.254049  [19200/60000]
# loss: 0.314413  [25600/60000]
# loss: 0.269692  [32000/60000]
# loss: 0.225736  [38400/60000]
# loss: 0.307955  [44800/60000]
# loss: 0.268209  [51200/60000]
# loss: 0.293637  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.362807
#
# Epoch 7
# -------------------------------
# loss: 0.212030  [    0/60000]
# loss: 0.207924  [ 6400/60000]
# loss: 0.205472  [12800/60000]
# loss: 0.233503  [19200/60000]
# loss: 0.292100  [25600/60000]
# loss: 0.247654  [32000/60000]
# loss: 0.201189  [38400/60000]
# loss: 0.295989  [44800/60000]
# loss: 0.284154  [51200/60000]
# loss: 0.272774  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.350006
#
# Epoch 8
# -------------------------------
# loss: 0.188575  [    0/60000]
# loss: 0.161486  [ 6400/60000]
# loss: 0.163101  [12800/60000]
# loss: 0.260192  [19200/60000]
# loss: 0.255469  [25600/60000]
# loss: 0.206350  [32000/60000]
# loss: 0.195329  [38400/60000]
# loss: 0.277571  [44800/60000]
# loss: 0.235561  [51200/60000]
# loss: 0.233184  [57600/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.376852
#
# Epoch 9
# -------------------------------
# loss: 0.192757  [    0/60000]
# loss: 0.157577  [ 6400/60000]
# loss: 0.179481  [12800/60000]
# loss: 0.226754  [19200/60000]
# loss: 0.259143  [25600/60000]
# loss: 0.227472  [32000/60000]
# loss: 0.205147  [38400/60000]
# loss: 0.269400  [44800/60000]
# loss: 0.178777  [51200/60000]
# loss: 0.273011  [57600/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.380562
#
# Epoch 10
# -------------------------------
# loss: 0.161610  [    0/60000]
# loss: 0.165668  [ 6400/60000]
# loss: 0.144862  [12800/60000]
# loss: 0.199187  [19200/60000]
# loss: 0.249141  [25600/60000]
# loss: 0.230401  [32000/60000]
# loss: 0.150683  [38400/60000]
# loss: 0.242342  [44800/60000]
# loss: 0.235710  [51200/60000]
# loss: 0.220704  [57600/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.415042
#
# Done!

# %% [markdown]
# **Expected output**:
#
# You can find that the training converges much faster using ADAM. For instance training after Epoch 1 with Adams yields a better performance than training after 10 epochs without Adams.
#
# ---
